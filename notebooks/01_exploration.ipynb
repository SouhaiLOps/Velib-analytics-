# %%
import sys, pandas as pd, numpy as np
print("python:", sys.executable)
print("pandas:", pd.__version__)
# Out:
# python: /Users/souhail/projets-ml/mon-premier-projet/.venv/bin/python
# pandas: 2.3.3
